# %%
import os 

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Recording input audio

import sounddevice as sd
from scipy.io.wavfile import write
import wavio as wv

# Sampling frequencytranscript
freq = 44100

# Recording duration in seconds
duration = 5

# Start recorder with the given values 
# of duration and sample frequency
recording = sd.rec(int(duration * freq), 
				samplerate=freq, channels=2)

# Record audio for the given number of seconds
sd.wait()

audio_file = "recording.wav"

# Convert the NumPy array to audio file
wv.write(audio_file, recording, freq, sampwidth=2)

# %%
#generating transcript from the recorded file 

from openai import OpenAI
client = OpenAI()

audio_file = open(audio_file, "rb")
transcript = client.audio.transcriptions.create(
  file=audio_file,
  model="whisper-1",
  response_format="text",
  # timestamp_granularities=["word"]
)

print(transcript)
# Out:
# Hey, how are you?

# %%
from langchain_openai.chat_models import ChatOpenAI

llm = ChatOpenAI()
llm_response = llm.invoke(transcript).content

# %%
voice_response = client.audio.speech.create(model="tts-1",
 voice="alloy",
  input=llm_response)

reponse_audio_file= "response.wav"
voice_response.write_to_file(reponse_audio_file)

# %%
#playing the response file

import IPython

IPython.display.Audio(reponse_audio_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
